# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#Load dataset

df_train = pd.read_csv('data/Train.csv')
df_test = pd.read_csv('data/Test.csv')
df_sample_submission = pd.read_csv('data/SampleSubmission.csv')

# %%
# Creating subsets of locations
#location_groups = df_train.groupby('Place_ID')
#type("location_groups")
#for location, sub_df in location_groups:
    # Sort each subset DataFrame by the 'Date' column in ascending order
#   sub_df = sub_df.sort_values(by='Date', ascending=True)
#  print(f"{location}:{sub_df}")


# Convert 'Date' to datetime if not already done
df_train['Date'] = pd.to_datetime(df_train['Date'])

# Create empty lists to store train and test DataFrames
train_dfs = []
test_dfs = []

# Creating subsets of locations
location_groups = df_train.groupby('Place_ID')

# Filter out groups that have fewer than 13 unique dates
filtered_groups = {
    location: sub_df for location, sub_df in location_groups 
    if sub_df['Date'].nunique() >= 13
}

# Debug: Print number of filtered groups
print(f"Number of filtered groups (locations with >=13 unique dates): {len(filtered_groups)}")

# Iterate through each filtered group
for location, sub_df in filtered_groups.items():
    # Sort each subset DataFrame by the 'Date' column in ascending order
    sub_df = sub_df.sort_values(by='Date', ascending=True)

    # Debug: Check the number of rows in the sorted sub_df
    print(f"Location: {location}, Number of rows: {len(sub_df)}")
    
    # Select the last three rows for the test set
    test_df = sub_df.tail(3)
    # Select the remaining rows for the train set
    train_df = sub_df.iloc[:-3]

     # Create a lag-1 variable for 'target' only in the training set
    train_df['lag_1'] = train_df['target'].shift(1)

    # Drop rows with NaN values in 'lag_1' (due to the shift)
    train_df = train_df.dropna(subset=['lag_1'])

    # Debug: Verify the number of rows in train and test sets for this location
    print(f"Location: {location}, Train Rows: {len(train_df)}, Test Rows: {len(test_df)}")

    # Append the split dataframes to their respective lists
    train_dfs.append(train_df)
    test_dfs.append(test_df)

# Concatenate all the train and test DataFrames into separate DataFrames
df_train_split = pd.concat(train_dfs, ignore_index=True)
df_test_split = pd.concat(test_dfs, ignore_index=True)

# Display or use the resulting DataFrames
print("Training set:")
print(df_train_split.head())  # Display the first few rows for verification
print("\nTest set:")
print(df_test_split.head())   # Display the first few rows for verification

# Optional: Check the number of rows in the test set for each location to verify correctness
print("\nNumber of rows per Place_ID in the test set:")
print(df_test_split['Place_ID'].value_counts())
# Out:
# Number of filtered groups (locations with >=13 unique dates): 337
# Location: 010Q650, Number of rows: 94
# Location: 010Q650, Train Rows: 90, Test Rows: 3
# Location: 05EC30X, Number of rows: 90
# Location: 05EC30X, Train Rows: 86, Test Rows: 3
# Location: 0DPWHX8, Number of rows: 94
# Location: 0DPWHX8, Train Rows: 90, Test Rows: 3
# Location: 0GBXTHY, Number of rows: 94
# Location: 0GBXTHY, Train Rows: 90, Test Rows: 3
# Location: 0HYPV1N, Number of rows: 94
# Location: 0HYPV1N, Train Rows: 90, Test Rows: 3
# Location: 0I2XREH, Number of rows: 65
# Location: 0I2XREH, Train Rows: 61, Test Rows: 3
# Location: 0KV6RJ1, Number of rows: 94
# Location: 0KV6RJ1, Train Rows: 90, Test Rows: 3
# Location: 0MGEY68, Number of rows: 94
# Location: 0MGEY68, Train Rows: 90, Test Rows: 3
# Location: 0O9R6AD, Number of rows: 92
# Location: 0O9R6AD, Train Rows: 88, Test Rows: 3
# Location: 0PP73FZ, Number of rows: 94
# Location: 0PP73FZ, Train Rows: 90, Test Rows: 3
# Location: 0RYZQUU, Number of rows: 91
# Location: 0RYZQUU, Train Rows: 87, Test Rows: 3
# Location: 0TFOCOS, Number of rows: 93
# Location: 0TFOCOS, Train Rows: 89, Test Rows: 3
# Location: 0TLH9UN, Number of rows: 94
# Location: 0TLH9UN, Train Rows: 90, Test Rows: 3
# Location: 11WPGRD, Number of rows: 94
# Location: 11WPGRD, Train Rows: 90, Test Rows: 3
# Location: 168B2T2, Number of rows: 94
# Location: 168B2T2, Train Rows: 90, Test Rows: 3
# Location: 1GZGJPN, Number of rows: 94
# Location: 1GZGJPN, Train Rows: 90, Test Rows: 3
# Location: 1LC5FAK, Number of rows: 94
# Location: 1LC5FAK, Train Rows: 90, Test Rows: 3
# Location: 1PRBF5P, Number of rows: 94
# Location: 1PRBF5P, Train Rows: 90, Test Rows: 3
# Location: 1RYCZPT, Number of rows: 94
# Location: 1RYCZPT, Train Rows: 90, Test Rows: 3
# Location: 1SC5AWD, Number of rows: 94
# Location: 1SC5AWD, Train Rows: 90, Test Rows: 3
# Location: 1SKLTGJ, Number of rows: 93
# Location: 1SKLTGJ, Train Rows: 89, Test Rows: 3
# Location: 1TE1HKJ, Number of rows: 79
# Location: 1TE1HKJ, Train Rows: 75, Test Rows: 3
# Location: 1UEYEJQ, Number of rows: 91
# Location: 1UEYEJQ, Train Rows: 87, Test Rows: 3
# Location: 1VN0K1S, Number of rows: 82
# Location: 1VN0K1S, Train Rows: 78, Test Rows: 3
# Location: 1WD100Y, Number of rows: 94
# Location: 1WD100Y, Train Rows: 90, Test Rows: 3
# Location: 1X421B8, Number of rows: 74
# Location: 1X421B8, Train Rows: 70, Test Rows: 3
# Location: 1Y0S7TZ, Number of rows: 49
# Location: 1Y0S7TZ, Train Rows: 45, Test Rows: 3
# Location: 1YXF6T3, Number of rows: 92
# Location: 1YXF6T3, Train Rows: 88, Test Rows: 3
# Location: 1Z0FIHB, Number of rows: 94
# Location: 1Z0FIHB, Train Rows: 90, Test Rows: 3
# Location: 1ZBVIMD, Number of rows: 91
# Location: 1ZBVIMD, Train Rows: 87, Test Rows: 3
# Location: 215BUAP, Number of rows: 94
# Location: 215BUAP, Train Rows: 90, Test Rows: 3
# Location: 22D7H7I, Number of rows: 92
# Location: 22D7H7I, Train Rows: 88, Test Rows: 3
# Location: 238N4KU, Number of rows: 94
# Location: 238N4KU, Train Rows: 90, Test Rows: 3
# Location: 28OSFYU, Number of rows: 94
# Location: 28OSFYU, Train Rows: 90, Test Rows: 3
# Location: 2JZW8ZM, Number of rows: 94
# Location: 2JZW8ZM, Train Rows: 90, Test Rows: 3
# Location: 2OR3E6X, Number of rows: 94
# Location: 2OR3E6X, Train Rows: 90, Test Rows: 3
# Location: 2S8UY1N, Number of rows: 94
# Location: 2S8UY1N, Train Rows: 90, Test Rows: 3
# Location: 2T41T7C, Number of rows: 94
# Location: 2T41T7C, Train Rows: 90, Test Rows: 3
# Location: 2USU80I, Number of rows: 94
# Location: 2USU80I, Train Rows: 90, Test Rows: 3
# Location: 2WABRKJ, Number of rows: 94
# Location: 2WABRKJ, Train Rows: 90, Test Rows: 3
# Location: 35YN53B, Number of rows: 94
# Location: 35YN53B, Train Rows: 90, Test Rows: 3
# Location: 37VXILV, Number of rows: 94
# Location: 37VXILV, Train Rows: 90, Test Rows: 3
# Location: 3EJ33BJ, Number of rows: 93
# Location: 3EJ33BJ, Train Rows: 89, Test Rows: 3
# Location: 3H1DEPM, Number of rows: 94
# Location: 3H1DEPM, Train Rows: 90, Test Rows: 3
# Location: 3HTVI1M, Number of rows: 94
# Location: 3HTVI1M, Train Rows: 90, Test Rows: 3
# Location: 3MXSVYJ, Number of rows: 88
# Location: 3MXSVYJ, Train Rows: 84, Test Rows: 3
# Location: 3V177MC, Number of rows: 94
# Location: 3V177MC, Train Rows: 90, Test Rows: 3
# Location: 3WZQJU8, Number of rows: 90
# Location: 3WZQJU8, Train Rows: 86, Test Rows: 3
# Location: 4085G7L, Number of rows: 80
# Location: 4085G7L, Train Rows: 76, Test Rows: 3
# Location: 426FKUG, Number of rows: 69
# Location: 426FKUG, Train Rows: 65, Test Rows: 3
# Location: 431JQGO, Number of rows: 94
# Location: 431JQGO, Train Rows: 90, Test Rows: 3
# Location: 4EVR9T8, Number of rows: 94
# Location: 4EVR9T8, Train Rows: 90, Test Rows: 3
# Location: 4IVJPF2, Number of rows: 94
# Location: 4IVJPF2, Train Rows: 90, Test Rows: 3
# Location: 4WA4C0T, Number of rows: 73
# Location: 4WA4C0T, Train Rows: 69, Test Rows: 3
# Location: 4XP6UOX, Number of rows: 94
# Location: 4XP6UOX, Train Rows: 90, Test Rows: 3
# Location: 4ZMC9UQ, Number of rows: 94
# Location: 4ZMC9UQ, Train Rows: 90, Test Rows: 3
# Location: 50JFNAG, Number of rows: 90
# Location: 50JFNAG, Train Rows: 86, Test Rows: 3
# Location: 57GIW0H, Number of rows: 84
# Location: 57GIW0H, Train Rows: 80, Test Rows: 3
# Location: 5ETAG9S, Number of rows: 94
# Location: 5ETAG9S, Train Rows: 90, Test Rows: 3
# Location: 5I4TI4R, Number of rows: 88
# Location: 5I4TI4R, Train Rows: 84, Test Rows: 3
# Location: 5IOL334, Number of rows: 94
# Location: 5IOL334, Train Rows: 90, Test Rows: 3
# Location: 5KE9R9R, Number of rows: 94
# Location: 5KE9R9R, Train Rows: 90, Test Rows: 3
# Location: 5M7ZX94, Number of rows: 94
# Location: 5M7ZX94, Train Rows: 90, Test Rows: 3
# Location: 5QYHA81, Number of rows: 90
# Location: 5QYHA81, Train Rows: 86, Test Rows: 3
# Location: 5SXR1G0, Number of rows: 91
# Location: 5SXR1G0, Train Rows: 87, Test Rows: 3
# Location: 5YBO7PQ, Number of rows: 94
# Location: 5YBO7PQ, Train Rows: 90, Test Rows: 3
# Location: 62HOUYZ, Number of rows: 94
# Location: 62HOUYZ, Train Rows: 90, Test Rows: 3
# Location: 693EWQR, Number of rows: 94
# Location: 693EWQR, Train Rows: 90, Test Rows: 3
# Location: 6CR3BYP, Number of rows: 94
# Location: 6CR3BYP, Train Rows: 90, Test Rows: 3
# Location: 6HXPCBH, Number of rows: 88
# Location: 6HXPCBH, Train Rows: 84, Test Rows: 3
# Location: 6J4AKCJ, Number of rows: 94
# Location: 6J4AKCJ, Train Rows: 90, Test Rows: 3
# Location: 6KHIOQ8, Number of rows: 94
# Location: 6KHIOQ8, Train Rows: 90, Test Rows: 3
# Location: 6O56XQX, Number of rows: 94
# Location: 6O56XQX, Train Rows: 90, Test Rows: 3
# Location: 6PWJJ6D, Number of rows: 94
# Location: 6PWJJ6D, Train Rows: 90, Test Rows: 3
# Location: 6SJG8N2, Number of rows: 94
# Location: 6SJG8N2, Train Rows: 90, Test Rows: 3
# Location: 6TF1KNR, Number of rows: 94
# Location: 6TF1KNR, Train Rows: 90, Test Rows: 3
# Location: 6TLEFED, Number of rows: 94
# Location: 6TLEFED, Train Rows: 90, Test Rows: 3
# Location: 6U70TX5, Number of rows: 93
# Location: 6U70TX5, Train Rows: 89, Test Rows: 3
# Location: 73GXFXK, Number of rows: 94
# Location: 73GXFXK, Train Rows: 90, Test Rows: 3
# Location: 7DRFQCK, Number of rows: 84
# Location: 7DRFQCK, Train Rows: 80, Test Rows: 3
# Location: 7LG0EUH, Number of rows: 94
# Location: 7LG0EUH, Train Rows: 90, Test Rows: 3
# Location: 7MO7ONT, Number of rows: 94
# Location: 7MO7ONT, Train Rows: 90, Test Rows: 3
# Location: 7NG0HSJ, Number of rows: 91
# Location: 7NG0HSJ, Train Rows: 87, Test Rows: 3
# Location: 7YE6PEV, Number of rows: 94
# Location: 7YE6PEV, Train Rows: 90, Test Rows: 3
# Location: 89GCPDD, Number of rows: 94
# Location: 89GCPDD, Train Rows: 90, Test Rows: 3
# Location: 8D88XH3, Number of rows: 94
# Location: 8D88XH3, Train Rows: 90, Test Rows: 3
# Location: 8HLVCJG, Number of rows: 94
# Location: 8HLVCJG, Train Rows: 90, Test Rows: 3
# Location: 8ISJ2N4, Number of rows: 49
# Location: 8ISJ2N4, Train Rows: 45, Test Rows: 3
# Location: 8OBB7UJ, Number of rows: 94
# Location: 8OBB7UJ, Train Rows: 90, Test Rows: 3
# Location: 8YYQSD3, Number of rows: 94
# Location: 8YYQSD3, Train Rows: 90, Test Rows: 3
# Location: 8ZGB2UV, Number of rows: 94
# Location: 8ZGB2UV, Train Rows: 90, Test Rows: 3
# Location: 8ZSYE9O, Number of rows: 94
# Location: 8ZSYE9O, Train Rows: 90, Test Rows: 3
# Location: 90AJCJ1, Number of rows: 94
# Location: 90AJCJ1, Train Rows: 90, Test Rows: 3
# Location: 92A8XLV, Number of rows: 93
# Location: 92A8XLV, Train Rows: 89, Test Rows: 3
# Location: 96GO3YA, Number of rows: 94
# Location: 96GO3YA, Train Rows: 90, Test Rows: 3
# Location: 99IA3IO, Number of rows: 94
# Location: 99IA3IO, Train Rows: 90, Test Rows: 3
# Location: 9BJURTV, Number of rows: 94
# Location: 9BJURTV, Train Rows: 90, Test Rows: 3
# Location: 9NOGUM2, Number of rows: 94
# Location: 9NOGUM2, Train Rows: 90, Test Rows: 3
# Location: 9YWJ0T2, Number of rows: 71
# Location: 9YWJ0T2, Train Rows: 67, Test Rows: 3
# Location: A0U3M42, Number of rows: 94
# Location: A0U3M42, Train Rows: 90, Test Rows: 3
# Location: A6F2SYU, Number of rows: 88
# Location: A6F2SYU, Train Rows: 84, Test Rows: 3
# Location: A8RN00Y, Number of rows: 94
# Location: A8RN00Y, Train Rows: 90, Test Rows: 3
# Location: AAXHBW0, Number of rows: 94
# Location: AAXHBW0, Train Rows: 90, Test Rows: 3
# Location: AKPYCSK, Number of rows: 94
# Location: AKPYCSK, Train Rows: 90, Test Rows: 3
# Location: ARTRJ6I, Number of rows: 93
# Location: ARTRJ6I, Train Rows: 89, Test Rows: 3
# Location: AXT8SS6, Number of rows: 94
# Location: AXT8SS6, Train Rows: 90, Test Rows: 3
# Location: B3AYS4E, Number of rows: 94
# Location: B3AYS4E, Train Rows: 90, Test Rows: 3
# Location: B42FR6O, Number of rows: 94
# Location: B42FR6O, Train Rows: 90, Test Rows: 3
# Location: B7XRCR9, Number of rows: 94
# Location: B7XRCR9, Train Rows: 90, Test Rows: 3
# Location: BFULCRB, Number of rows: 94
# Location: BFULCRB, Train Rows: 90, Test Rows: 3
# Location: BI2CD3X, Number of rows: 94
# Location: BI2CD3X, Train Rows: 90, Test Rows: 3
# Location: BIWFBLL, Number of rows: 68
# Location: BIWFBLL, Train Rows: 64, Test Rows: 3
# Location: BJKCK1G, Number of rows: 94
# Location: BJKCK1G, Train Rows: 90, Test Rows: 3
# Location: BM82F5C, Number of rows: 94
# Location: BM82F5C, Train Rows: 90, Test Rows: 3
# Location: BOKENQL, Number of rows: 94
# Location: BOKENQL, Train Rows: 90, Test Rows: 3
# Location: BQMJO3V, Number of rows: 94
# Location: BQMJO3V, Train Rows: 90, Test Rows: 3
# Location: BS86L9J, Number of rows: 69
# Location: BS86L9J, Train Rows: 65, Test Rows: 3
# Location: C146N8V, Number of rows: 94
# Location: C146N8V, Train Rows: 90, Test Rows: 3
# Location: C39T5GU, Number of rows: 92
# Location: C39T5GU, Train Rows: 88, Test Rows: 3
# Location: C8ZQ12G, Number of rows: 94
# Location: C8ZQ12G, Train Rows: 90, Test Rows: 3
# Location: C97SU6H, Number of rows: 94
# Location: C97SU6H, Train Rows: 90, Test Rows: 3
# Location: CKVKV15, Number of rows: 92
# Location: CKVKV15, Train Rows: 88, Test Rows: 3
# Location: CKWC5RK, Number of rows: 93
# Location: CKWC5RK, Train Rows: 89, Test Rows: 3
# Location: CREKDCU, Number of rows: 94
# Location: CREKDCU, Train Rows: 90, Test Rows: 3
# Location: CTOEK4L, Number of rows: 94
# Location: CTOEK4L, Train Rows: 90, Test Rows: 3
# Location: CUQYTBO, Number of rows: 94
# Location: CUQYTBO, Train Rows: 90, Test Rows: 3
# Location: CX6SRPO, Number of rows: 85
# Location: CX6SRPO, Train Rows: 81, Test Rows: 3
# Location: D1G84CB, Number of rows: 94
# Location: D1G84CB, Train Rows: 90, Test Rows: 3
# Location: D1OBVR6, Number of rows: 89
# Location: D1OBVR6, Train Rows: 85, Test Rows: 3
# Location: D41QK7I, Number of rows: 94
# Location: D41QK7I, Train Rows: 90, Test Rows: 3
# Location: D7K9KM7, Number of rows: 94
# Location: D7K9KM7, Train Rows: 90, Test Rows: 3
# Location: DALZSBE, Number of rows: 94
# Location: DALZSBE, Train Rows: 90, Test Rows: 3
# Location: DC6LSFX, Number of rows: 94
# Location: DC6LSFX, Train Rows: 90, Test Rows: 3
# Location: DCBEVTO, Number of rows: 94
# Location: DCBEVTO, Train Rows: 90, Test Rows: 3
# Location: DDMR0JF, Number of rows: 92
# Location: DDMR0JF, Train Rows: 88, Test Rows: 3
# Location: DDN3QS2, Number of rows: 84
# Location: DDN3QS2, Train Rows: 80, Test Rows: 3
# Location: DG199GT, Number of rows: 88
# Location: DG199GT, Train Rows: 84, Test Rows: 3
# Location: DHRND6U, Number of rows: 91
# Location: DHRND6U, Train Rows: 87, Test Rows: 3
# Location: DHVQZD8, Number of rows: 94
# Location: DHVQZD8, Train Rows: 90, Test Rows: 3
# Location: DIHJFZ0, Number of rows: 93
# Location: DIHJFZ0, Train Rows: 89, Test Rows: 3
# Location: DPQKOA5, Number of rows: 94
# Location: DPQKOA5, Train Rows: 90, Test Rows: 3
# Location: DRFD4D1, Number of rows: 94
# Location: DRFD4D1, Train Rows: 90, Test Rows: 3
# Location: DSG5LHH, Number of rows: 94
# Location: DSG5LHH, Train Rows: 90, Test Rows: 3
# Location: DSGAHLQ, Number of rows: 92
# Location: DSGAHLQ, Train Rows: 88, Test Rows: 3
# Location: DXU9CSJ, Number of rows: 94
# Location: DXU9CSJ, Train Rows: 90, Test Rows: 3
# Location: DXV3CMF, Number of rows: 91
# Location: DXV3CMF, Train Rows: 87, Test Rows: 3
# Location: E05B6AD, Number of rows: 94
# Location: E05B6AD, Train Rows: 90, Test Rows: 3
# Location: E3IZI9K, Number of rows: 94
# Location: E3IZI9K, Train Rows: 90, Test Rows: 3
# Location: E3VXRRJ, Number of rows: 94
# Location: E3VXRRJ, Train Rows: 90, Test Rows: 3
# Location: E7N9S0X, Number of rows: 94
# Location: E7N9S0X, Train Rows: 90, Test Rows: 3
# Location: E9KQB8A, Number of rows: 94
# Location: E9KQB8A, Train Rows: 90, Test Rows: 3
# Location: ECCAPWQ, Number of rows: 94
# Location: ECCAPWQ, Train Rows: 90, Test Rows: 3
# Location: EE8C6RP, Number of rows: 94
# Location: EE8C6RP, Train Rows: 90, Test Rows: 3
# Location: EVB4HVG, Number of rows: 94
# Location: EVB4HVG, Train Rows: 90, Test Rows: 3
# Location: EVXOAKQ, Number of rows: 94
# Location: EVXOAKQ, Train Rows: 90, Test Rows: 3
# Location: F51ZEA7, Number of rows: 94
# Location: F51ZEA7, Train Rows: 90, Test Rows: 3
# Location: F7I9EOT, Number of rows: 76
# Location: F7I9EOT, Train Rows: 72, Test Rows: 3
# Location: F9780KK, Number of rows: 94
# Location: F9780KK, Train Rows: 90, Test Rows: 3
# Location: FAYY7HV, Number of rows: 94
# Location: FAYY7HV, Train Rows: 90, Test Rows: 3
# Location: FFK3RNL, Number of rows: 94
# Location: FFK3RNL, Train Rows: 90, Test Rows: 3
# Location: FH6B9N5, Number of rows: 94
# Location: FH6B9N5, Train Rows: 90, Test Rows: 3
# Location: FLN66MS, Number of rows: 94
# Location: FLN66MS, Train Rows: 90, Test Rows: 3
# Location: FOQIF0X, Number of rows: 94
# Location: FOQIF0X, Train Rows: 90, Test Rows: 3
# Location: FUTHSQ2, Number of rows: 94
# Location: FUTHSQ2, Train Rows: 90, Test Rows: 3
# Location: FW7AVMW, Number of rows: 94
# Location: FW7AVMW, Train Rows: 90, Test Rows: 3
# Location: FZ0DA1F, Number of rows: 88
# Location: FZ0DA1F, Train Rows: 84, Test Rows: 3
# Location: G4CKKFV, Number of rows: 94
# Location: G4CKKFV, Train Rows: 90, Test Rows: 3
# Location: G7NMF97, Number of rows: 79
# Location: G7NMF97, Train Rows: 75, Test Rows: 3
# Location: G9VUTNV, Number of rows: 68
# Location: G9VUTNV, Train Rows: 64, Test Rows: 3
# Location: GGVKSLX, Number of rows: 94
# Location: GGVKSLX, Train Rows: 90, Test Rows: 3
# Location: GJOPSKI, Number of rows: 90
# Location: GJOPSKI, Train Rows: 86, Test Rows: 3
# Location: GLPQ01R, Number of rows: 92
# Location: GLPQ01R, Train Rows: 88, Test Rows: 3
# Location: GNHAWDW, Number of rows: 94
# Location: GNHAWDW, Train Rows: 90, Test Rows: 3
# Location: GP8V3PO, Number of rows: 94
# Location: GP8V3PO, Train Rows: 90, Test Rows: 3
# Location: GR52CEZ, Number of rows: 91
# Location: GR52CEZ, Train Rows: 87, Test Rows: 3
# Location: GSIMFXX, Number of rows: 94
# Location: GSIMFXX, Train Rows: 90, Test Rows: 3
# Location: GU2Z4N6, Number of rows: 94
# Location: GU2Z4N6, Train Rows: 90, Test Rows: 3
# Location: H2FJ6F6, Number of rows: 79
# Location: H2FJ6F6, Train Rows: 75, Test Rows: 3
# Location: H6JSAYZ, Number of rows: 94
# Location: H6JSAYZ, Train Rows: 90, Test Rows: 3
# Location: H7QOMTD, Number of rows: 94
# Location: H7QOMTD, Train Rows: 90, Test Rows: 3
# Location: HCGAOBY, Number of rows: 91
# Location: HCGAOBY, Train Rows: 87, Test Rows: 3
# Location: HFRRK3M, Number of rows: 79
# Location: HFRRK3M, Train Rows: 75, Test Rows: 3
# Location: HN3YMTM, Number of rows: 94
# Location: HN3YMTM, Train Rows: 90, Test Rows: 3
# Location: HNXHLWA, Number of rows: 91
# Location: HNXHLWA, Train Rows: 87, Test Rows: 3
# Location: HPOVPNA, Number of rows: 91
# Location: HPOVPNA, Train Rows: 87, Test Rows: 3
# Location: HR0OKCA, Number of rows: 94
# Location: HR0OKCA, Train Rows: 90, Test Rows: 3
# Location: HRUE894, Number of rows: 94
# Location: HRUE894, Train Rows: 90, Test Rows: 3
# Location: HSXRMLA, Number of rows: 94
# Location: HSXRMLA, Train Rows: 90, Test Rows: 3
# Location: I5RGE5G, Number of rows: 94
# Location: I5RGE5G, Train Rows: 90, Test Rows: 3
# Location: I6718VY, Number of rows: 94
# Location: I6718VY, Train Rows: 90, Test Rows: 3
# Location: I6VIR8R, Number of rows: 94
# Location: I6VIR8R, Train Rows: 90, Test Rows: 3
# Location: IJKTQ0G, Number of rows: 94
# Location: IJKTQ0G, Train Rows: 90, Test Rows: 3
# Location: IKRWFY4, Number of rows: 88
# Location: IKRWFY4, Train Rows: 84, Test Rows: 3
# Location: IM6VR3X, Number of rows: 94
# Location: IM6VR3X, Train Rows: 90, Test Rows: 3
# Location: IOLPRPO, Number of rows: 94
# Location: IOLPRPO, Train Rows: 90, Test Rows: 3
# Location: IST2SPS, Number of rows: 94
# Location: IST2SPS, Train Rows: 90, Test Rows: 3
# Location: IXVOHYQ, Number of rows: 94
# Location: IXVOHYQ, Train Rows: 90, Test Rows: 3
# Location: J39EIKN, Number of rows: 94
# Location: J39EIKN, Train Rows: 90, Test Rows: 3
# Location: J3C3IAI, Number of rows: 93
# Location: J3C3IAI, Train Rows: 89, Test Rows: 3
# Location: J3HFUPO, Number of rows: 94
# Location: J3HFUPO, Train Rows: 90, Test Rows: 3
# Location: J4UZBX3, Number of rows: 94
# Location: J4UZBX3, Train Rows: 90, Test Rows: 3
# Location: J8IR9R2, Number of rows: 94
# Location: J8IR9R2, Train Rows: 90, Test Rows: 3
# Location: JABMGKI, Number of rows: 94
# Location: JABMGKI, Train Rows: 90, Test Rows: 3
# Location: JID7N54, Number of rows: 94
# Location: JID7N54, Train Rows: 90, Test Rows: 3
# Location: JK1Y6T7, Number of rows: 91
# Location: JK1Y6T7, Train Rows: 87, Test Rows: 3
# Location: JRPE3E8, Number of rows: 69
# Location: JRPE3E8, Train Rows: 65, Test Rows: 3
# Location: JSXAVKO, Number of rows: 94
# Location: JSXAVKO, Train Rows: 90, Test Rows: 3
# Location: JY4I65T, Number of rows: 69
# Location: JY4I65T, Train Rows: 65, Test Rows: 3
# Location: KB7LD9K, Number of rows: 94
# Location: KB7LD9K, Train Rows: 90, Test Rows: 3
# Location: KRT9EQD, Number of rows: 91
# Location: KRT9EQD, Train Rows: 87, Test Rows: 3
# Location: KXX7F64, Number of rows: 94
# Location: KXX7F64, Train Rows: 90, Test Rows: 3
# Location: KYNZWCA, Number of rows: 94
# Location: KYNZWCA, Train Rows: 90, Test Rows: 3
# Location: KZJQU9F, Number of rows: 94
# Location: KZJQU9F, Train Rows: 90, Test Rows: 3
# Location: L17O89H, Number of rows: 94
# Location: L17O89H, Train Rows: 90, Test Rows: 3
# Location: L686B2W, Number of rows: 94
# Location: L686B2W, Train Rows: 90, Test Rows: 3
# Location: LBFYBY5, Number of rows: 84
# Location: LBFYBY5, Train Rows: 80, Test Rows: 3
# Location: LF5EAJD, Number of rows: 94
# Location: LF5EAJD, Train Rows: 90, Test Rows: 3
# Location: LKE9VQB, Number of rows: 41
# Location: LKE9VQB, Train Rows: 37, Test Rows: 3
# Location: LSK9OJP, Number of rows: 92
# Location: LSK9OJP, Train Rows: 88, Test Rows: 3
# Location: LVBKULK, Number of rows: 88
# Location: LVBKULK, Train Rows: 84, Test Rows: 3
# Location: LXRFONN, Number of rows: 94
# Location: LXRFONN, Train Rows: 90, Test Rows: 3
# Location: M17FYGT, Number of rows: 94
# Location: M17FYGT, Train Rows: 90, Test Rows: 3
# Location: M53IXJM, Number of rows: 94
# Location: M53IXJM, Train Rows: 90, Test Rows: 3
# Location: ME8O4BV, Number of rows: 93
# Location: ME8O4BV, Train Rows: 89, Test Rows: 3
# Location: MUJVVNA, Number of rows: 94
# Location: MUJVVNA, Train Rows: 90, Test Rows: 3
# Location: N5RI4GT, Number of rows: 94
# Location: N5RI4GT, Train Rows: 90, Test Rows: 3
# Location: NCIFTFE, Number of rows: 94
# Location: NCIFTFE, Train Rows: 90, Test Rows: 3
# Location: NHB348L, Number of rows: 94
# Location: NHB348L, Train Rows: 90, Test Rows: 3
# Location: NJ1G8AW, Number of rows: 94
# Location: NJ1G8AW, Train Rows: 90, Test Rows: 3
# Location: NKXVNIW, Number of rows: 88
# Location: NKXVNIW, Train Rows: 84, Test Rows: 3
# Location: NMX4N9O, Number of rows: 88
# Location: NMX4N9O, Train Rows: 84, Test Rows: 3
# Location: NW6MZ2E, Number of rows: 94
# Location: NW6MZ2E, Train Rows: 90, Test Rows: 3
# Location: OCJ6GWU, Number of rows: 94
# Location: OCJ6GWU, Train Rows: 90, Test Rows: 3
# Location: OE6VS93, Number of rows: 94
# Location: OE6VS93, Train Rows: 90, Test Rows: 3
# Location: OEN2305, Number of rows: 94
# Location: OEN2305, Train Rows: 90, Test Rows: 3
# Location: OU23QHQ, Number of rows: 94
# Location: OU23QHQ, Train Rows: 90, Test Rows: 3
# Location: P0TB067, Number of rows: 86
# Location: P0TB067, Train Rows: 82, Test Rows: 3
# Location: PA1M3UV, Number of rows: 93
# Location: PA1M3UV, Train Rows: 89, Test Rows: 3
# Location: PCEC7FM, Number of rows: 94
# Location: PCEC7FM, Train Rows: 90, Test Rows: 3
# Location: PCGUGKH, Number of rows: 94
# Location: PCGUGKH, Train Rows: 90, Test Rows: 3
# Location: PHOW9EM, Number of rows: 94
# Location: PHOW9EM, Train Rows: 90, Test Rows: 3
# Location: PJ8AOXN, Number of rows: 94
# Location: PJ8AOXN, Train Rows: 90, Test Rows: 3
# Location: PWER8U4, Number of rows: 94
# Location: PWER8U4, Train Rows: 90, Test Rows: 3
# Location: Q0IXA5X, Number of rows: 94
# Location: Q0IXA5X, Train Rows: 90, Test Rows: 3
# Location: Q17XPXH, Number of rows: 94
# Location: Q17XPXH, Train Rows: 90, Test Rows: 3
# Location: Q2F2SPS, Number of rows: 94
# Location: Q2F2SPS, Train Rows: 90, Test Rows: 3
# Location: Q724ZY2, Number of rows: 94
# Location: Q724ZY2, Train Rows: 90, Test Rows: 3
# Location: Q9LESDG, Number of rows: 94
# Location: Q9LESDG, Train Rows: 90, Test Rows: 3
# Location: QENS5WN, Number of rows: 94
# Location: QENS5WN, Train Rows: 90, Test Rows: 3
# Location: QFNUGSK, Number of rows: 93
# Location: QFNUGSK, Train Rows: 89, Test Rows: 3
# Location: QHM3GGJ, Number of rows: 94
# Location: QHM3GGJ, Train Rows: 90, Test Rows: 3
# Location: QJXIO6H, Number of rows: 94
# Location: QJXIO6H, Train Rows: 90, Test Rows: 3
# Location: QNLDXFV, Number of rows: 94
# Location: QNLDXFV, Train Rows: 90, Test Rows: 3
# Location: QO3SZZ5, Number of rows: 94
# Location: QO3SZZ5, Train Rows: 90, Test Rows: 3
# Location: QU0HBVG, Number of rows: 94
# Location: QU0HBVG, Train Rows: 90, Test Rows: 3
# Location: QUNY99Q, Number of rows: 94
# Location: QUNY99Q, Train Rows: 90, Test Rows: 3
# Location: R0N919B, Number of rows: 94
# Location: R0N919B, Train Rows: 90, Test Rows: 3
# Location: R8CIARR, Number of rows: 94
# Location: R8CIARR, Train Rows: 90, Test Rows: 3
# Location: R9PQN4I, Number of rows: 62
# Location: R9PQN4I, Train Rows: 58, Test Rows: 3
# Location: RFQQX9G, Number of rows: 94
# Location: RFQQX9G, Train Rows: 90, Test Rows: 3
# Location: RPUU1F6, Number of rows: 71
# Location: RPUU1F6, Train Rows: 67, Test Rows: 3
# Location: RW9SZRD, Number of rows: 94
# Location: RW9SZRD, Train Rows: 90, Test Rows: 3
# Location: RWKDYP8, Number of rows: 94
# Location: RWKDYP8, Train Rows: 90, Test Rows: 3
# Location: S0WW3QJ, Number of rows: 94
# Location: S0WW3QJ, Train Rows: 90, Test Rows: 3
# Location: S32B9IH, Number of rows: 94
# Location: S32B9IH, Train Rows: 90, Test Rows: 3
# Location: S5THXEQ, Number of rows: 94
# Location: S5THXEQ, Train Rows: 90, Test Rows: 3
# Location: S7IJ6XS, Number of rows: 94
# Location: S7IJ6XS, Train Rows: 90, Test Rows: 3
# Location: S91MBTB, Number of rows: 29
# Location: S91MBTB, Train Rows: 25, Test Rows: 3
# Location: S9GAHFC, Number of rows: 94
# Location: S9GAHFC, Train Rows: 90, Test Rows: 3
# Location: SA4513B, Number of rows: 94
# Location: SA4513B, Train Rows: 90, Test Rows: 3
# Location: SCACE8F, Number of rows: 94
# Location: SCACE8F, Train Rows: 90, Test Rows: 3
# Location: SE7OCTI, Number of rows: 90
# Location: SE7OCTI, Train Rows: 86, Test Rows: 3
# Location: SEX1T9W, Number of rows: 94
# Location: SEX1T9W, Train Rows: 90, Test Rows: 3
# Location: SI12552, Number of rows: 93
# Location: SI12552, Train Rows: 89, Test Rows: 3
# Location: SIPXZIA, Number of rows: 69
# Location: SIPXZIA, Train Rows: 65, Test Rows: 3
# Location: SVT8GRZ, Number of rows: 94
# Location: SVT8GRZ, Train Rows: 90, Test Rows: 3
# Location: SWUJIDU, Number of rows: 94
# Location: SWUJIDU, Train Rows: 90, Test Rows: 3
# Location: SX68COZ, Number of rows: 80
# Location: SX68COZ, Train Rows: 76, Test Rows: 3
# Location: T0Q4SUD, Number of rows: 94
# Location: T0Q4SUD, Train Rows: 90, Test Rows: 3
# Location: T1GU8DC, Number of rows: 91
# Location: T1GU8DC, Train Rows: 87, Test Rows: 3
# Location: T4KAD07, Number of rows: 93
# Location: T4KAD07, Train Rows: 89, Test Rows: 3
# Location: T5P5MTS, Number of rows: 42
# Location: T5P5MTS, Train Rows: 38, Test Rows: 3
# Location: T6AW5VC, Number of rows: 94
# Location: T6AW5VC, Train Rows: 90, Test Rows: 3
# Location: TEANSOU, Number of rows: 93
# Location: TEANSOU, Train Rows: 89, Test Rows: 3
# Location: THZR2TS, Number of rows: 94
# Location: THZR2TS, Train Rows: 90, Test Rows: 3
# Location: TIIYG30, Number of rows: 94
# Location: TIIYG30, Train Rows: 90, Test Rows: 3
# Location: TK9EJLZ, Number of rows: 94
# Location: TK9EJLZ, Train Rows: 90, Test Rows: 3
# Location: TKTT8QV, Number of rows: 94
# Location: TKTT8QV, Train Rows: 90, Test Rows: 3
# Location: TQTUGH0, Number of rows: 79
# Location: TQTUGH0, Train Rows: 75, Test Rows: 3
# Location: TRD3XUN, Number of rows: 92
# Location: TRD3XUN, Train Rows: 88, Test Rows: 3
# Location: TSWW4S1, Number of rows: 94
# Location: TSWW4S1, Train Rows: 90, Test Rows: 3
# Location: TV0K4Y7, Number of rows: 94
# Location: TV0K4Y7, Train Rows: 90, Test Rows: 3
# Location: TXXYRS3, Number of rows: 92
# Location: TXXYRS3, Train Rows: 88, Test Rows: 3
# Location: U3ABGNY, Number of rows: 94
# Location: U3ABGNY, Train Rows: 90, Test Rows: 3
# Location: U91NAMJ, Number of rows: 48
# Location: U91NAMJ, Train Rows: 44, Test Rows: 3
# Location: UB2EP6X, Number of rows: 94
# Location: UB2EP6X, Train Rows: 90, Test Rows: 3
# Location: UB4SRN5, Number of rows: 94
# Location: UB4SRN5, Train Rows: 90, Test Rows: 3
# Location: UC3HU0F, Number of rows: 91
# Location: UC3HU0F, Train Rows: 87, Test Rows: 3
# Location: UEEK36P, Number of rows: 94
# Location: UEEK36P, Train Rows: 90, Test Rows: 3
# Location: UF34PPS, Number of rows: 94
# Location: UF34PPS, Train Rows: 90, Test Rows: 3
# Location: UJSFMHD, Number of rows: 94
# Location: UJSFMHD, Train Rows: 90, Test Rows: 3
# Location: UNO965G, Number of rows: 94
# Location: UNO965G, Train Rows: 90, Test Rows: 3
# Location: URSY7IS, Number of rows: 94
# Location: URSY7IS, Train Rows: 90, Test Rows: 3
# Location: UUAY1R8, Number of rows: 94
# Location: UUAY1R8, Train Rows: 90, Test Rows: 3
# Location: UXIIFC9, Number of rows: 93
# Location: UXIIFC9, Train Rows: 89, Test Rows: 3
# Location: V16MEEV, Number of rows: 94
# Location: V16MEEV, Train Rows: 90, Test Rows: 3
# Location: V18LR2F, Number of rows: 94
# Location: V18LR2F, Train Rows: 90, Test Rows: 3
# Location: V2J713I, Number of rows: 94
# Location: V2J713I, Train Rows: 90, Test Rows: 3
# Location: V9H35TO, Number of rows: 94
# Location: V9H35TO, Train Rows: 90, Test Rows: 3
# Location: VH4P13S, Number of rows: 94
# Location: VH4P13S, Train Rows: 90, Test Rows: 3
# Location: VHZ9CYS, Number of rows: 94
# Location: VHZ9CYS, Train Rows: 90, Test Rows: 3
# Location: VLWCTOI, Number of rows: 94
# Location: VLWCTOI, Train Rows: 90, Test Rows: 3
# Location: VPEDEBQ, Number of rows: 94
# Location: VPEDEBQ, Train Rows: 90, Test Rows: 3
# Location: VQ64B9Z, Number of rows: 94
# Location: VQ64B9Z, Train Rows: 90, Test Rows: 3
# Location: W6AECQZ, Number of rows: 94
# Location: W6AECQZ, Train Rows: 90, Test Rows: 3
# Location: WMD80ZE, Number of rows: 94
# Location: WMD80ZE, Train Rows: 90, Test Rows: 3
# Location: WNYYRYS, Number of rows: 94
# Location: WNYYRYS, Train Rows: 90, Test Rows: 3
# Location: WOIRN9J, Number of rows: 94
# Location: WOIRN9J, Train Rows: 90, Test Rows: 3
# Location: WP7PTYQ, Number of rows: 94
# Location: WP7PTYQ, Train Rows: 90, Test Rows: 3
# Location: WQP8SI3, Number of rows: 94
# Location: WQP8SI3, Train Rows: 90, Test Rows: 3
# Location: WRK50NS, Number of rows: 82
# Location: WRK50NS, Train Rows: 78, Test Rows: 3
# Location: WT1TF7C, Number of rows: 85
# Location: WT1TF7C, Train Rows: 81, Test Rows: 3
# Location: WY9VXCA, Number of rows: 57
# Location: WY9VXCA, Train Rows: 53, Test Rows: 3
# Location: XJJSC4X, Number of rows: 49
# Location: XJJSC4X, Train Rows: 45, Test Rows: 3
# Location: XY3IU5C, Number of rows: 94
# Location: XY3IU5C, Train Rows: 90, Test Rows: 3
# Location: Y14BIVM, Number of rows: 93
# Location: Y14BIVM, Train Rows: 89, Test Rows: 3
# Location: YAAFH6B, Number of rows: 94
# Location: YAAFH6B, Train Rows: 90, Test Rows: 3
# Location: YAQHNNY, Number of rows: 94
# Location: YAQHNNY, Train Rows: 90, Test Rows: 3
# Location: YAXBMZ6, Number of rows: 94
# Location: YAXBMZ6, Train Rows: 90, Test Rows: 3
# Location: YCXA4V5, Number of rows: 94
# Location: YCXA4V5, Train Rows: 90, Test Rows: 3
# Location: YDW4K0H, Number of rows: 88
# Location: YDW4K0H, Train Rows: 84, Test Rows: 3
# Location: YJENTFL, Number of rows: 70
# Location: YJENTFL, Train Rows: 66, Test Rows: 3
# Location: YLLOKEY, Number of rows: 94
# Location: YLLOKEY, Train Rows: 90, Test Rows: 3
# Location: YLZOBFW, Number of rows: 94
# Location: YLZOBFW, Train Rows: 90, Test Rows: 3
# Location: YPXSK14, Number of rows: 94
# Location: YPXSK14, Train Rows: 90, Test Rows: 3
# Location: YSIXKFZ, Number of rows: 94
# Location: YSIXKFZ, Train Rows: 90, Test Rows: 3
# Location: YWSFY6Q, Number of rows: 78
# Location: YWSFY6Q, Train Rows: 74, Test Rows: 3
# Training set:
#         Place_ID X Date       Date Place_ID  target  target_min  target_max
# 0  010Q650 X 2020-01-03 2020-01-03  010Q650    39.0        25.0        63.0  \
# 1  010Q650 X 2020-01-04 2020-01-04  010Q650    24.0         8.0        56.0
# 2  010Q650 X 2020-01-05 2020-01-05  010Q650    49.0        10.0        55.0
# 3  010Q650 X 2020-01-06 2020-01-06  010Q650    21.0         9.0        52.0
# 4  010Q650 X 2020-01-07 2020-01-07  010Q650    28.0        10.0        52.0
#
#    target_variance  target_count  precipitable_water_entire_atmosphere
# 0          1319.85            91                             14.600000  \
# 1          1181.96            96                             16.400000
# 2          1113.67            96                              6.911948
# 3          1164.82            95                             13.900001
# 4          1053.22            94                             14.600000
#
#    relative_humidity_2m_above_ground  ...  L3_SO2_solar_azimuth_angle
# 0                          48.799999  ...                  -67.693509  \
# 1                          33.400002  ...                  -78.342701
# 2                          21.300001  ...                  -73.896588
# 3                          44.700001  ...                  -68.612480
# 4                          42.200001  ...                  -62.134264
#
#    L3_SO2_solar_zenith_angle  L3_CH4_CH4_column_volume_mixing_ratio_dry_air
# 0                  28.614804                                    1789.960449  \
# 1                  34.296977                                            NaN
# 2                  30.545446                                            NaN
# 3                  26.899694                                            NaN
# 4                  23.419991                                            NaN
#
#    L3_CH4_aerosol_height  L3_CH4_aerosol_optical_depth
# 0            3384.226562                      0.015104  \
# 1                    NaN                           NaN
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4                    NaN                           NaN
#
#    L3_CH4_sensor_azimuth_angle  L3_CH4_sensor_zenith_angle
# 0                    75.630043                   55.657486  \
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#    L3_CH4_solar_azimuth_angle  L3_CH4_solar_zenith_angle  lag_1
# 0                  -53.868134                  19.293652   38.0
# 1                         NaN                        NaN   39.0
# 2                         NaN                        NaN   24.0
# 3                         NaN                        NaN   49.0
# 4                         NaN                        NaN   21.0
#
# [5 rows x 83 columns]
#
# Test set:
#         Place_ID X Date       Date Place_ID  target  target_min  target_max
# 0  010Q650 X 2020-04-02 2020-04-02  010Q650    59.0        51.0        73.0  \
# 1  010Q650 X 2020-04-03 2020-04-03  010Q650    61.0        52.0        69.0
# 2  010Q650 X 2020-04-04 2020-04-04  010Q650    45.0        25.0        62.0
# 3  05EC30X X 2020-04-02 2020-04-02  05EC30X    13.0         9.0        46.0
# 4  05EC30X X 2020-04-03 2020-04-03  05EC30X    17.0         9.0        34.0
#
#    target_variance  target_count  precipitable_water_entire_atmosphere
# 0           261.12            96                              5.670641  \
# 1           210.58            96                              6.100000
# 2          1186.51            96                              5.500000
# 3           986.50            24                             16.958141
# 4           591.50            23                             18.262501
#
#    relative_humidity_2m_above_ground  ...  L3_SO2_sensor_zenith_angle
# 0                          32.600002  ...                         NaN  \
# 1                          17.500000  ...                    0.000000
# 2                          17.500000  ...                   44.105635
# 3                          76.325003  ...                   54.435454
# 4                          67.000001  ...                    0.000000
#
#    L3_SO2_solar_azimuth_angle  L3_SO2_solar_zenith_angle
# 0                         NaN                        NaN  \
# 1                    0.000000                   0.000000
# 2                  -46.289380                  53.377209
# 3                  -27.849405                  37.879518
# 4                    0.000000                   0.000000
#
#    L3_CH4_CH4_column_volume_mixing_ratio_dry_air  L3_CH4_aerosol_height
# 0                                            NaN                    NaN  \
# 1                                       0.000000               0.000000
# 2                                    1808.852905            3028.596436
# 3                                            NaN                    NaN
# 4                                       0.000000               0.000000
#
#    L3_CH4_aerosol_optical_depth  L3_CH4_sensor_azimuth_angle
# 0                           NaN                          NaN  \
# 1                      0.000000                     0.000000
# 2                      0.008327                  -103.123833
# 3                           NaN                          NaN
# 4                      0.000000                     0.000000
#
#    L3_CH4_sensor_zenith_angle  L3_CH4_solar_azimuth_angle
# 0                         NaN                         NaN  \
# 1                    0.000000                    0.000000
# 2                   45.017094                  -46.496193
# 3                         NaN                         NaN
# 4                    0.000000                    0.000000
#
#    L3_CH4_solar_zenith_angle
# 0                        NaN
# 1                   0.000000
# 2                  53.573624
# 3                        NaN
# 4                   0.000000
#
# [5 rows x 82 columns]
#
# Number of rows per Place_ID in the test set:
# Place_ID
# 010Q650    3
# M53IXJM    3
# NMX4N9O    3
# NKXVNIW    3
# NJ1G8AW    3
#           ..
# BIWFBLL    3
# BI2CD3X    3
# BFULCRB    3
# B7XRCR9    3
# YWSFY6Q    3
# Name: count, Length: 337, dtype: int64

# %%
## MODEL 1 LIGHTGBM

from lightgbm import LGBMRegressor
from lightgbm import LGBMRegressor, early_stopping, log_evaluation
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

# Define the feature columns and target
feature_columns = [
    'Place_ID',
    'precipitable_water_entire_atmosphere',
    'relative_humidity_2m_above_ground',
    'specific_humidity_2m_above_ground', 
    'temperature_2m_above_ground',
    'u_component_of_wind_10m_above_ground',
    'v_component_of_wind_10m_above_ground',
    'L3_NO2_NO2_column_number_density',
    'L3_NO2_NO2_slant_column_number_density',
    'L3_NO2_absorbing_aerosol_index', 
    'L3_NO2_cloud_fraction',
    'L3_NO2_sensor_altitude', 
    'L3_NO2_sensor_azimuth_angle',
    'L3_NO2_sensor_zenith_angle', 
    'L3_NO2_solar_azimuth_angle',
    'L3_NO2_solar_zenith_angle',
    'L3_NO2_stratospheric_NO2_column_number_density',
    'L3_NO2_tropopause_pressure',
    'L3_NO2_tropospheric_NO2_column_number_density',
    'L3_O3_O3_column_number_density', 
    'L3_O3_O3_effective_temperature',
    'L3_O3_cloud_fraction', 
    'L3_O3_sensor_azimuth_angle',
    'L3_O3_sensor_zenith_angle', 
    'L3_O3_solar_azimuth_angle',
    'L3_O3_solar_zenith_angle',
    'L3_CO_CO_column_number_density',
    'L3_CO_H2O_column_number_density', 
    'L3_CO_cloud_height',
    'L3_CO_sensor_altitude', 
    'L3_CO_sensor_azimuth_angle',
    'L3_CO_sensor_zenith_angle', 
    'L3_CO_solar_azimuth_angle',
    'L3_CO_solar_zenith_angle', 
    'L3_HCHO_HCHO_slant_column_number_density',
    'L3_HCHO_cloud_fraction', 
    'L3_HCHO_sensor_azimuth_angle',
    'L3_HCHO_sensor_zenith_angle', 
    'L3_HCHO_solar_azimuth_angle',
    'L3_HCHO_solar_zenith_angle',
    'L3_HCHO_tropospheric_HCHO_column_number_density',
    'L3_HCHO_tropospheric_HCHO_column_number_density_amf',
    'L3_CLOUD_cloud_base_height', 
    'L3_CLOUD_cloud_base_pressure',
    'L3_CLOUD_cloud_fraction', 
    'L3_CLOUD_cloud_optical_depth',
    'L3_CLOUD_cloud_top_height', 
    'L3_CLOUD_cloud_top_pressure',
    'L3_CLOUD_sensor_azimuth_angle', 
    'L3_CLOUD_sensor_zenith_angle',
    'L3_CLOUD_solar_azimuth_angle', 
    'L3_CLOUD_solar_zenith_angle',
    'L3_CLOUD_surface_albedo', 
    'L3_AER_AI_absorbing_aerosol_index',
    'L3_AER_AI_sensor_altitude', 
    'L3_AER_AI_sensor_azimuth_angle',
    'L3_AER_AI_sensor_zenith_angle', 
    'L3_AER_AI_solar_azimuth_angle',
    'L3_AER_AI_solar_zenith_angle', 
    'L3_SO2_SO2_column_number_density',
    'L3_SO2_SO2_column_number_density_amf',
    'L3_SO2_SO2_slant_column_number_density',
    'L3_SO2_absorbing_aerosol_index', 
    'L3_SO2_cloud_fraction',
    'L3_SO2_sensor_azimuth_angle', 
    'L3_SO2_sensor_zenith_angle',
    'L3_SO2_solar_azimuth_angle', 
    'L3_SO2_solar_zenith_angle',
    'L3_CH4_CH4_column_volume_mixing_ratio_dry_air',
    'L3_CH4_aerosol_height', 
    'L3_CH4_aerosol_optical_depth',
    'L3_CH4_sensor_azimuth_angle', 
    'L3_CH4_sensor_zenith_angle',
    'L3_CH4_solar_azimuth_angle', 
    'L3_CH4_solar_zenith_angle'
]
# Prepare the training and testing data
X_train = df_train_split[feature_columns]
y_train = df_train_split['target']
X_test = df_test_split[feature_columns]
y_test = df_test_split['target']

# Encode the 'Place_ID' as it is a categorical feature
label_encoder = LabelEncoder()
X_train['Place_ID'] = label_encoder.fit_transform(X_train['Place_ID'])
X_test['Place_ID'] = label_encoder.transform(X_test['Place_ID'])

# Define the LightGBM model using the scikit-learn API
model = LGBMRegressor(
    objective='regression',
    learning_rate=0.05,
    n_estimators=1000,
    num_leaves=31,
    max_depth=-1,
    min_data_in_leaf=20,
    feature_fraction=0.8,
    bagging_fraction=0.8,
    bagging_freq=5,
    random_state=42
)

# Train the model with early stopping
model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    eval_metric='rmse',
    callbacks=[early_stopping(stopping_rounds=50), log_evaluation(period=100)],
)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007133 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19113
# [LightGBM] [Info] Number of data points in the train set: 29187, number of used features: 75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Info] Start training from score 61.263360
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 26.8532	valid_0's l2: 721.096
# [200]	valid_0's rmse: 26.1322	valid_0's l2: 682.891
# [300]	valid_0's rmse: 25.7081	valid_0's l2: 660.907
# [400]	valid_0's rmse: 25.7006	valid_0's l2: 660.519
# Early stopping, best iteration is:
# [379]	valid_0's rmse: 25.4241	valid_0's l2: 646.384
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# Root Mean Squared Error (RMSE): 25.424079804978554

# %%
# MODEL 2 (incl. date variables)

from lightgbm import LGBMRegressor, early_stopping, log_evaluation
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np

# Step 1: Sort data by Place_ID and Date
df_train_split = df_train_split.sort_values(by=['Place_ID', 'Date'])
df_test_split = df_test_split.sort_values(by=['Place_ID', 'Date'])

# Step 2: Create 'day_number' and 'is_weekend' features

# Convert 'Date' to datetime format if not already done
df_train_split['Date'] = pd.to_datetime(df_train_split['Date'])
df_test_split['Date'] = pd.to_datetime(df_test_split['Date'])

# Calculate 'day_number' (days since the first date per Place_ID)
df_train_split['day_number'] = df_train_split.groupby('Place_ID')['Date'].transform(lambda x: (x - x.min()).dt.days)
df_test_split['day_number'] = df_test_split.groupby('Place_ID')['Date'].transform(lambda x: (x - x.min()).dt.days)

# Create 'is_weekend' (1 if weekend, 0 if weekday)
df_train_split['is_weekend'] = df_train_split['Date'].dt.weekday.isin([5, 6]).astype(int)
df_test_split['is_weekend'] = df_test_split['Date'].dt.weekday.isin([5, 6]).astype(int)

# Step 3: Update the feature columns list to include the new features
feature_columns = [
    'Place_ID',
    'precipitable_water_entire_atmosphere',
    'relative_humidity_2m_above_ground',
    'specific_humidity_2m_above_ground', 
    'temperature_2m_above_ground',
    'u_component_of_wind_10m_above_ground',
    'v_component_of_wind_10m_above_ground',
    'L3_NO2_NO2_column_number_density',
    'L3_NO2_NO2_slant_column_number_density',
    'L3_NO2_absorbing_aerosol_index', 
    'L3_NO2_cloud_fraction',
    'L3_NO2_sensor_altitude', 
    'L3_NO2_sensor_azimuth_angle',
    'L3_NO2_sensor_zenith_angle', 
    'L3_NO2_solar_azimuth_angle',
    'L3_NO2_solar_zenith_angle',
    'L3_NO2_stratospheric_NO2_column_number_density',
    'L3_NO2_tropopause_pressure',
    'L3_NO2_tropospheric_NO2_column_number_density',
    'L3_O3_O3_column_number_density', 
    'L3_O3_O3_effective_temperature',
    'L3_O3_cloud_fraction', 
    'L3_O3_sensor_azimuth_angle',
    'L3_O3_sensor_zenith_angle', 
    'L3_O3_solar_azimuth_angle',
    'L3_O3_solar_zenith_angle',
    'L3_CO_CO_column_number_density',
    'L3_CO_H2O_column_number_density', 
    'L3_CO_cloud_height',
    'L3_CO_sensor_altitude', 
    'L3_CO_sensor_azimuth_angle',
    'L3_CO_sensor_zenith_angle', 
    'L3_CO_solar_azimuth_angle',
    'L3_CO_solar_zenith_angle', 
    'L3_HCHO_HCHO_slant_column_number_density',
    'L3_HCHO_cloud_fraction', 
    'L3_HCHO_sensor_azimuth_angle',
    'L3_HCHO_sensor_zenith_angle', 
    'L3_HCHO_solar_azimuth_angle',
    'L3_HCHO_solar_zenith_angle',
    'L3_HCHO_tropospheric_HCHO_column_number_density',
    'L3_HCHO_tropospheric_HCHO_column_number_density_amf',
    'L3_CLOUD_cloud_base_height', 
    'L3_CLOUD_cloud_base_pressure',
    'L3_CLOUD_cloud_fraction', 
    'L3_CLOUD_cloud_optical_depth',
    'L3_CLOUD_cloud_top_height', 
    'L3_CLOUD_cloud_top_pressure',
    'L3_CLOUD_sensor_azimuth_angle', 
    'L3_CLOUD_sensor_zenith_angle',
    'L3_CLOUD_solar_azimuth_angle', 
    'L3_CLOUD_solar_zenith_angle',
    'L3_CLOUD_surface_albedo', 
    'L3_AER_AI_absorbing_aerosol_index',
    'L3_AER_AI_sensor_altitude', 
    'L3_AER_AI_sensor_azimuth_angle',
    'L3_AER_AI_sensor_zenith_angle', 
    'L3_AER_AI_solar_azimuth_angle',
    'L3_AER_AI_solar_zenith_angle', 
    'L3_SO2_SO2_column_number_density',
    'L3_SO2_SO2_column_number_density_amf',
    'L3_SO2_SO2_slant_column_number_density',
    'L3_SO2_absorbing_aerosol_index', 
    'L3_SO2_cloud_fraction',
    'L3_SO2_sensor_azimuth_angle', 
    'L3_SO2_sensor_zenith_angle',
    'L3_SO2_solar_azimuth_angle', 
    'L3_SO2_solar_zenith_angle',
    'L3_CH4_CH4_column_volume_mixing_ratio_dry_air',
    'L3_CH4_aerosol_height', 
    'L3_CH4_aerosol_optical_depth',
    'L3_CH4_sensor_azimuth_angle', 
    'L3_CH4_sensor_zenith_angle',
    'L3_CH4_solar_azimuth_angle', 
    'L3_CH4_solar_zenith_angle',
    'day_number',  # Include day_number feature
    'is_weekend'   # Include is_weekend feature
]

# Prepare the training and testing data with the new features
X_train = df_train_split[feature_columns]
y_train = df_train_split['target']
X_test = df_test_split[feature_columns]
y_test = df_test_split['target']

# Encode the 'Place_ID' as it is a categorical feature
label_encoder = LabelEncoder()
X_train['Place_ID'] = label_encoder.fit_transform(X_train['Place_ID'])
X_test['Place_ID'] = label_encoder.transform(X_test['Place_ID'])

# Define the LightGBM model using the scikit-learn API
model = LGBMRegressor(
    objective='regression',
    learning_rate=0.05,
    n_estimators=1000,
    num_leaves=31,
    max_depth=-1,
    min_data_in_leaf=20,
    feature_fraction=0.8,
    bagging_fraction=0.8,
    bagging_freq=5,
    random_state=42
)

# Train the model with early stopping
model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    eval_metric='rmse',
    callbacks=[early_stopping(stopping_rounds=50), log_evaluation(period=100)],
)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006839 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19205
# [LightGBM] [Info] Number of data points in the train set: 29187, number of used features: 77
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Info] Start training from score 61.263360
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 27.7057	valid_0's l2: 767.607
# [200]	valid_0's rmse: 27.0971	valid_0's l2: 734.251
# Early stopping, best iteration is:
# [156]	valid_0's rmse: 27.0437	valid_0's l2: 731.361
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# Root Mean Squared Error (RMSE): 27.043692262683706

# %%
# Check if 'lag_1' exists in the training dataset and move it to the end
#if 'lag_1' in df_train_split.columns:
   # Get all columns except 'lag_1'
   # #  cols = [col for col in df_train_split.columns if col != 'lag_1']
    # Add 'lag_1' as the last column
  #  df_train_split = df_train_split[cols + ['lag_1']]
   # print("'lag_1' has been moved to the last position in the training dataset.")
#else:
 #   print("'lag_1' does not exist in the training dataset.")

# %%
# MODEL 3 (excl. some features)

# Step 1: Sort data by Place_ID and Date
df_train_split = df_train_split.sort_values(by=['Place_ID', 'Date'])
df_test_split = df_test_split.sort_values(by=['Place_ID', 'Date'])

# Step 2: Create 'day_number' and 'is_weekend' features

# Convert 'Date' to datetime format if not already done
df_train_split['Date'] = pd.to_datetime(df_train_split['Date'])
df_test_split['Date'] = pd.to_datetime(df_test_split['Date'])

# Calculate 'day_number' (days since the first date per Place_ID)
df_train_split['day_number'] = df_train_split.groupby('Place_ID')['Date'].transform(lambda x: (x - x.min()).dt.days)
df_test_split['day_number'] = df_test_split.groupby('Place_ID')['Date'].transform(lambda x: (x - x.min()).dt.days)

# Create 'is_weekend' (1 if weekend, 0 if weekday)
df_train_split['is_weekend'] = df_train_split['Date'].dt.weekday.isin([5, 6]).astype(int)
df_test_split['is_weekend'] = df_test_split['Date'].dt.weekday.isin([5, 6]).astype(int)

# Step 3: Update the feature columns list to include the new features
feature_columns = [
    'Place_ID',
    "L3_CO_CO_column_number_density",
    "L3_HCHO_tropospheric_HCHO_column_number_density",
    "L3_NO2_NO2_column_number_density",
    "L3_O3_O3_column_number_density",
    "u_component_of_wind_10m_above_ground",
    'day_number',  # Include day_number feature
    'is_weekend'   # Include is_weekend feature
]

# Prepare the training and testing data with the new features
X_train = df_train_split[feature_columns]
y_train = df_train_split['target']
X_test = df_test_split[feature_columns]
y_test = df_test_split['target']

# Encode the 'Place_ID' as it is a categorical feature
label_encoder = LabelEncoder()
X_train['Place_ID'] = label_encoder.fit_transform(X_train['Place_ID'])
X_test['Place_ID'] = label_encoder.transform(X_test['Place_ID'])

# Define the LightGBM model using the scikit-learn API
model = LGBMRegressor(
    objective='regression',
    learning_rate=0.05,
    n_estimators=1000,
    num_leaves=31,
    max_depth=-1,
    min_data_in_leaf=20,
    feature_fraction=0.8,
    bagging_fraction=0.8,
    bagging_freq=5,
    random_state=42
)

# Train the model with early stopping
model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    eval_metric='rmse',
    callbacks=[early_stopping(stopping_rounds=50), log_evaluation(period=100)],
)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000618 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1610
# [LightGBM] [Info] Number of data points in the train set: 29187, number of used features: 8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Info] Start training from score 61.263360
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	valid_0's rmse: 30.963	valid_0's l2: 958.71
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# Root Mean Squared Error (RMSE): 30.963048795148396
