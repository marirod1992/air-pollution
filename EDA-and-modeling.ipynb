# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# sample data
sample_=pd.read_csv("data/SampleSubmission.csv")

# test

test_=pd.read_csv("data/Test.csv")

# train

train_=pd.read_csv("data/Train.csv")

# %% [markdown]
# SAMPLE
# . Place_ID X Date split
# . target = 0 ?
#
# --> what is our key to compare?

# %%
sample_.head(1)
# Out:
#         Place_ID X Date  target
# 0  0OS9LVX X 2020-01-02       0

# %%
sample_.nunique()
# Out:
# Place_ID X Date    16136
# target                 1
# dtype: int64

# %%
sample_.describe
# Out:
# <bound method NDFrame.describe of             Place_ID X Date  target
# 0      0OS9LVX X 2020-01-02       0
# 1      0OS9LVX X 2020-01-03       0
# 2      0OS9LVX X 2020-01-04       0
# 3      0OS9LVX X 2020-01-05       0
# 4      0OS9LVX X 2020-01-06       0
# 5      0OS9LVX X 2020-01-07       0
# 6      0OS9LVX X 2020-01-08       0
# 7      0OS9LVX X 2020-01-09       0
# 8      0OS9LVX X 2020-01-10       0
# 9      0OS9LVX X 2020-01-11       0
# 10     0OS9LVX X 2020-01-12       0
# 11     0OS9LVX X 2020-01-13       0
# 12     0OS9LVX X 2020-01-14       0
# 13     0OS9LVX X 2020-01-15       0
# 14     0OS9LVX X 2020-01-16       0
# 15     0OS9LVX X 2020-01-17       0
# 16     0OS9LVX X 2020-01-18       0
# 17     0OS9LVX X 2020-01-19       0
# 18     0OS9LVX X 2020-01-20       0
# 19     0OS9LVX X 2020-01-21       0
# 20     0OS9LVX X 2020-01-22       0
# 21     0OS9LVX X 2020-01-23       0
# 22     0OS9LVX X 2020-01-24       0
# 23     0OS9LVX X 2020-01-25       0
# ...

# %%
test_.head(1)
# Out:
#         Place_ID X Date        Date Place_ID
# 0  0OS9LVX X 2020-01-02  2020-01-02  0OS9LVX  \
#
#    precipitable_water_entire_atmosphere  relative_humidity_2m_above_ground
# 0                                  11.6                          30.200001  \
#
#    specific_humidity_2m_above_ground  temperature_2m_above_ground
# 0                            0.00409                    14.656824  \
#
#    u_component_of_wind_10m_above_ground  v_component_of_wind_10m_above_ground
# 0                              3.956377                              0.712605  \
#
#    L3_NO2_NO2_column_number_density  ...  L3_SO2_sensor_zenith_angle
# 0                          0.000053  ...                    1.445658  \
#
#    L3_SO2_solar_azimuth_angle  L3_SO2_solar_zenith_angle
# 0                  -95.984984                  22.942019  \
#
#    L3_CH4_CH4_column_volume_mixing_ratio_dry_air  L3_CH4_aerosol_height
# 0                                            NaN                    NaN  \
#
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
test_.nunique()
# Out:
# Place_ID X Date                                        16136
# Date                                                      94
# Place_ID                                                 179
# precipitable_water_entire_atmosphere                    7077
# relative_humidity_2m_above_ground                       6305
# specific_humidity_2m_above_ground                      11730
# temperature_2m_above_ground                            15768
# u_component_of_wind_10m_above_ground                   15452
# v_component_of_wind_10m_above_ground                   15500
# L3_NO2_NO2_column_number_density                       13438
# L3_NO2_NO2_slant_column_number_density                 13438
# L3_NO2_absorbing_aerosol_index                         13438
# L3_NO2_cloud_fraction                                  13344
# L3_NO2_sensor_altitude                                 13438
# L3_NO2_sensor_azimuth_angle                            13438
# ...

# %%
test_.describe()
# Out:
#        precipitable_water_entire_atmosphere
# count                          16136.000000  \
# mean                              14.202076
# std                                9.377060
# min                                0.900000
# 25%                                7.655303
# 50%                               11.600000
# 75%                               18.100000
# max                               63.100002
#
#        relative_humidity_2m_above_ground  specific_humidity_2m_above_ground
# count                       16136.000000                       16136.000000  \
# mean                           71.136312                           0.005513
# std                            18.357542                           0.003261
# min                             6.700000                           0.000279
# 25%                            60.000000                           0.003401
# 50%                            74.800003                           0.004610
# ...

# %%
train_.head(1)
# Out:
#         Place_ID X Date        Date Place_ID  target  target_min  target_max
# 0  010Q650 X 2020-01-02  2020-01-02  010Q650    38.0        23.0        53.0  \
#
#    target_variance  target_count  precipitable_water_entire_atmosphere
# 0            769.5            92                                  11.0  \
#
#    relative_humidity_2m_above_ground  ...  L3_SO2_sensor_zenith_angle
# 0                          60.200001  ...                   38.593017  \
#
#    L3_SO2_solar_azimuth_angle  L3_SO2_solar_zenith_angle
# 0                  -61.752587                  22.363665  \
#
#    L3_CH4_CH4_column_volume_mixing_ratio_dry_air  L3_CH4_aerosol_height
# 0                                    1793.793579            3227.855469  \
#
#    L3_CH4_aerosol_optical_depth  L3_CH4_sensor_azimuth_angle
# 0                      0.010579                    74.481049  \
#
#    L3_CH4_sensor_zenith_angle  L3_CH4_solar_azimuth_angle
# 0                   37.501499                  -62.142639  \
#
# ...

# %%
train_.describe()
# Out:
#              target    target_min    target_max  target_variance
# count  30557.000000  30557.000000  30557.000000     3.055700e+04  \
# mean      61.148045     29.025866    117.992234     7.983756e+03
# std       46.861309     33.119775    100.417713     4.863090e+04
# min        1.000000      1.000000      1.000000     0.000000e+00
# 25%       25.000000      5.000000     60.000000     1.064920e+03
# 50%       50.000000     15.000000     91.000000     2.395350e+03
# 75%       80.000000     44.000000    155.000000     5.882550e+03
# max      815.000000    438.000000    999.000000     1.841490e+06
#
#        target_count  precipitable_water_entire_atmosphere
# count  30557.000000                          30557.000000  \
# mean     125.831135                             15.302326
# std      146.581856                             10.688573
# min        2.000000                              0.420044
# 25%       44.000000                              7.666667
# ...

# %%
train_.nunique()
# Out:
# Place_ID X Date                                        30557
# Date                                                      94
# Place_ID                                                 340
# target                                                   375
# target_min                                               269
# target_max                                               721
# target_variance                                        29621
# target_count                                             863
# precipitable_water_entire_atmosphere                   12633
# relative_humidity_2m_above_ground                      11284
# specific_humidity_2m_above_ground                      21396
# temperature_2m_above_ground                            29462
# u_component_of_wind_10m_above_ground                   28240
# v_component_of_wind_10m_above_ground                   28274
# L3_NO2_NO2_column_number_density                       25758
# ...

# %%
# Check for columns present in train_ but not in test_
train_not_in_test = set(train_.columns) - set(test_.columns)
# Check for columns present in test_ but not in train_
test_not_in_train = set(test_.columns) - set(train_.columns)

print("Columns in train_ but not in test_:", train_not_in_test)
print("Columns in test_ but not in train_:", test_not_in_train)
# Out:
# Columns in train_ but not in test_: {'target', 'target_count', 'target_min', 'target_max', 'target_variance'}
# Columns in test_ but not in train_: set()

# %%
# Compare data types
data_type_mismatch = []
for col in set(train_.columns).intersection(set(test_.columns)):
    if train_[col].dtype != test_[col].dtype:
        data_type_mismatch.append(col)

print("Columns with different data types:", data_type_mismatch)
# Out:
# Columns with different data types: []

# %% [markdown]
# # Data cleaningin and feature engineering

# %%
coffee_features.info()

# %%
#for this exercise we will only deal with numeric variables

X = coffee_features.select_dtypes(['number'])

# %% [markdown]
# ## Splitting data for testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
#dropping Quakers column and unnamed
#changing one of the altitude to log and droping the original
X_train["altitude_mean_log"] = np.log(X_train["altitude_mean_meters"])
X_train.drop(['altitude_mean_meters'], axis=1, inplace=True)
X_train.drop(['Quakers'], axis=1, inplace=True)
X_train.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
X_train.info()

# %%
altitude_low_meters_mean = X_train["altitude_low_meters"].mean()
altitude_high_meters_mean = X_train["altitude_high_meters"].mean()
altitude_mean_log_mean = X_train["altitude_mean_log"].mean()

# %%
# fillna with mean.. 
X_train["altitude_low_meters"] = X_train["altitude_low_meters"].fillna(altitude_low_meters_mean)
X_train["altitude_high_meters"] = X_train["altitude_high_meters"].fillna(altitude_high_meters_mean)
X_train["altitude_mean_log"] = X_train["altitude_mean_log"].fillna(altitude_mean_log_mean)

# %%
print(f"altitude low meters mean is {altitude_low_meters_mean}")
print(f"altitude_high_meters_mean is {altitude_high_meters_mean}")
print(f"altitude_mean_log_mean is {altitude_mean_log_mean}")

# %% [markdown]
# ## Trainining the model

# %%
## in order to exemplify how the predict will work.. we will save the y_train
X_test.to_csv("data/X_test.csv")
y_test.to_csv("data/y_test.csv")

# %%
#training the model
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)

# %%
from sklearn.metrics import mean_squared_error
y_train_pred = reg.predict(X_train)
mse = mean_squared_error(y_train, y_train_pred)
print(mse)

# %%
#dropping Quakers column and unnamed
#changing one of the altitude to log and droping the original
X_test["altitude_mean_log"] = np.log(X_test["altitude_mean_meters"])
X_test.drop(['altitude_mean_meters'], axis=1, inplace=True)
X_test.drop(['Quakers'], axis=1, inplace=True)
X_test.drop(['Unnamed: 0'], axis=1, inplace=True)
# fillna with mean.. 
X_test["altitude_low_meters"] = X_test["altitude_low_meters"].fillna(altitude_low_meters_mean)
X_test["altitude_high_meters"] = X_test["altitude_high_meters"].fillna(altitude_high_meters_mean)
X_test["altitude_mean_log"] = X_test["altitude_mean_log"].fillna(altitude_mean_log_mean)

# %%
y_test_pred = reg.predict(X_test)
mse = mean_squared_error(y_test, y_test_pred)
print(mse)
